# %%
# l = (1,2,3,4,5,6,7)
# print(type(l))
# print(2*l) #constant multiplications
# L=l+l
# print(L)  # addition 
# print(2*l)
# l2 = [2,3,4,5,6,7]

# M=2*l2
# print(M)

# l= 2*l
# print(l)
# l2= 2*l2
# print(type(l2))
# print(l2)

# print(2*l2)

# #SET
# S1= {1,2,3,4,1}
# print(type(S1))

# print(S1)

# S2 = {2,4,5,6,7,8}
# S=S1-S2 #Intersection
# print(S)

# #Dictonary

# dict1 = {'a':1,'b':2}
# dict2 = {'b':2,'a':1}

# def find_square(n):
#     return n*n

# n = int(input('Enter a num : '))
# S = find_square(n)
# print(S)


# Fact=1

# def fact(num):
#     fact=1
#     for i in range(1,num+1):
#          fact*=i
#     return fact    

# N= int(input('Enter a number : '))
# factorial=fact(N)
# print(factorial)

def sum_n(N):
    sum=0
    for i in range(1,N+1):
        sum+=i

    return sum

Num = int(input('Enter a number : '))
n_natural = sum_n(Num)
print(n_natural)
# Out:
# Enter a number :  100
# 5050
